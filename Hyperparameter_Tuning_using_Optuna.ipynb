# %% [markdown]
# # Hyperparameter
#
# 1. Parameters ✅
#
# Model khud learning ke time seekhta hai.
#
# Example:
#
# Linear Regression → Weight (w), Bias (b)
# Neural Network → Weights
#
# Ye automatically learn hote hain.
#
# 2. Hyperparameters ✅
#
# Ye model khud nahi seekhta.
#
# Ye hum set karte hain training se pehle.
#
# Examples
#
# Learning Rate
#
# Number of Trees
#
# Max Depth
#
# Batch Size
#
# Epochs
#
# Number of Neighbors (KNN)
#
# Problem
#
# Suppose tum Random Forest bana rahe ho.
#
# Question:
#
# Kitne Trees?
#
# 10?
#
# 100?
#
# 500?
#
# Max Depth?
#
# 5?
#
# 10?
#
# 20?
#
# Kaunsi value best hai?
#
# Hume nahi pata.
#
# Isi process ko kehte hain
#
# Hyperparameter Tuning

# %% [markdown]
# # Optuna
#
# Optuna ek intelligent hyperparameter tuner hai.
#
# Ye blindly combinations try nahi karta.
#
# Ye previous results dekhkar decide karta hai
#
# "Agli baar kya try karna chahiye."
#
# Isliye
#
# ✅ Faster
#
# ✅ Smarter
#
# ✅ Better

# %% [markdown]
# # Easy Analogy 🎯
#
# Treasure Hunt.
#
# 100 Boxes hain.
#
# Grid Search
#
# Sab boxes kholo.
#
# Bahut time.
#
# Random Search
#
# Random 20 boxes kholo.
#
# Lucky hue to mil jayega.

# %% [markdown]
# # Optuna
#
# Pehle kuch boxes dekhta hai.
#
# Fir sochta hai
#
# "Gold shayad left side mein hai."
#
# Fir wahi area mein aur search karta hai.
#
# Matlab
#
# Past experience se seekhta hai.
#
# Isi wajah se fast hai.

# %% [markdown]
# # Optuna Ka Workflow
#
# Start
#
# ↓
#
# Choose Hyperparameters
#
# ↓
#
# Train Model
#
# ↓
#
# Evaluate Accuracy
#
# ↓
#
# Save Result
#
# ↓
#
# Smart Algorithm Sochta Hai
#
# ↓
#
# Better Hyperparameters
#
# ↓
#
# Repeat
#
# ↓
#
# Best Parameters

# %% [markdown]
# # Optuna ka Brain
#
# Har trial ke baad ye compare karta hai.
#
# Example
#
# Trial 1
#
# Trees =100
#
# Depth=5
#
# Accuracy=85%
# Trial 2
#
# Trees=200
#
# Depth=10
#
# Accuracy=90%
#
# Ab Optuna sochta hai
#
# 200 acha tha.
#
# Chalo 220 ya 250 try karte hain.
#
# Instead of
#
# 1000 Trees
#
# Depth 50
#
# Matlab intelligent guessing.

# %% [markdown]
# # Trial Kya Hota Hai?
#
# Ek experiment.
#
# Example
#
# Trial 1
#
# Learning Rate = 0.1
#
# Depth = 5
#
# Accuracy = 88%
#
# Trial 2
#
# Learning Rate = 0.05
#
# Depth =10
#
# Accuracy =91%
#
# Har experiment = 1 Trial

# %% [markdown]
# # Study Kya Hai?
#
# Sab trials ka collection.
#
# Study
#
# |
# |-- Trial 1
#
# |-- Trial 2
#
# |-- Trial 3
#
# |-- Trial 4
#
# End me
#
# Study batata hai
#
# Best Trial
#
# Best Parameters
#
# Best Accuracy

# %% [markdown]
# # Objective Function
#
# Ye Optuna ka exam paper hai.
#
# Isme likhte hain
#
# Hyperparameters suggest karo
# Model train karo
# Accuracy return karo
#
# Simple Flow
#
# Input
#
# ↓
#
# Hyperparameters
#
# ↓
#
# Train Model
#
# ↓
#
# Accuracy
#
# ↓
#
# Return Accuracy

# %% [markdown]
# # Example

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)

def objective(trial):

    n_estimators = trial.suggest_int("n_estimators", 50, 300)

    max_depth = trial.suggest_int("max_depth", 2, 20)

    clf = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=42
    )

    score = cross_val_score(clf, X, y, cv=5).mean()

    return score

study = optuna.create_study(direction="maximize")

study.optimize(objective, n_trials=20)

print(study.best_params)
print(study.best_value)

# %% [markdown]
# # Common suggest_* Functions
#
# | Function                                                                                   | Use                             |
# | ------------------------------------------------------------------------------------------ | ------------------------------- |
# | `suggest_int()`                                                                            | Integer values                  |
# | `suggest_float()`                                                                          | Decimal values                  |
# | `suggest_categorical()`                                                                    | Fixed options                   |
# | `suggest_loguniform()` *(older API; use `suggest_float(..., log=True)` in newer versions)* | Values over a logarithmic scale |

# %% [markdown]
# # Why Optuna?
#
# ✅ Easy to use
#
# ✅ Faster than Grid Search
#
# ✅ Smarter than Random Search
#
# ✅ Finds better hyperparameters
#
# ✅ Saves computation time
#
# ✅ Works with almost every ML/DL library (Scikit-learn, XGBoost, LightGBM, TensorFlow, PyTorch, etc.)

# %% [markdown]
# # Bayesian Optimization using Optuna
#
# Sabse Pehle Problem Samjho
#
# Suppose tumhare paas ek ML model hai.
#
# Tumhe best accuracy chahiye.
#
# Tumhare paas ye hyperparameters hain:
#
# Learning Rate
#
# Max Depth
#
# Number of Trees
#
# Question:
#
# Kaunsi values best hongi?
#
# Hum nahi jaante.
#
# Isi problem ko solve karta hai Bayesian Optimization.

# %% [markdown]
#  # Real-Life Analogy 🎯
#
# Imagine ek treasure hunt hai.
#
# 1000 boxes hain.
#
# Sirf 1 box mein gold hai.
#
# Method 1: Grid Search
# Open every box.
#
# 1
# 2
# 3
# 4
# 5
# ...
# 1000
#
# ✔ Gold mil jayega.
#
# ❌ Bahut time lagega.
#
# Method 2: Random Search
# Randomly boxes kholo.
#
# 12
# 58
# 900
# 34
# 781
#
# ✔ Fast
#
# ❌ Gold miss bhi ho sakta hai.
#
# Method 3: Bayesian Optimization
#
# Ye smart detective ki tarah kaam karta hai.
#
# Pehle 5–10 boxes dekhta hai.
#
# Fir sochta hai:
#
# "Gold shayad isi area mein hoga."
#
# Ab wahi aas-paas search karta hai.
#
# Har naye result se aur intelligent hota jata hai.
#
# Yahi Bayesian Optimization hai.

# %% [markdown]
#  # Bayesian Optimization ek smart search algorithm hai jo previous trials se seekhkar next hyperparameters choose karta hai, taaki best result kam trials mein mil sake.

# %% [markdown]
# # Iska Main Idea
#
# Har trial ke baad Optuna 2 questions puchta hai:
#
# Question 1
#
# Ab tak best result kaha mila?
#
# Learning Rate = 0.01
#
# Accuracy = 95%
# Question 2
#
# Uske aas-paas aur check karein?
#
# 0.008
#
# 0.009
#
# 0.012
#
# 0.015
#
# Instead of trying
#
# 0.9
#
# 0.8
#
# 0.7

# %% [markdown]
# # Ek Example
#
# Suppose
#
# Trial 1
#
# Learning Rate = 0.1
#
# Accuracy = 82%
#
# Trial 2
#
# Learning Rate = 0.01
#
# Accuracy = 93%
#
# Trial 3
#
# Bayesian Optimization sochta hai
#
# 0.01 achha tha
#
# Chalo
#
# 0.009
#
# 0.012
#
# 0.015
#
# Trial 4
#
# Learning Rate = 0.012
#
# Accuracy = 95%
#
# Ab aur nearby search karega.

# %% [markdown]
# # Ye Smart Kaise Hai?
#
# Har trial ke baad ye ek mathematical model (surrogate model) banata hai.
#
# Ye estimate karta hai:
#
# Agar yaha hyperparameter try karunga,
# to accuracy kitni ho sakti hai?
#
# Actual model ko baar-baar train karne ki jagah pehle prediction karta hai.
#
# Isliye fast hai.

# %% [markdown]
# # Two Important Concepts
# 1. Exploitation
#
# Jo area already achha lag raha hai,
# usi ke aas-paas search karna.
#
# Example
#
# 0.01
#
# ↓
#
# 0.011
#
# ↓
#
# 0.012
#
# ↓
#
# 0.013
#
# Goal:
#
# Best accuracy ko aur improve karna.
#
# 2. Exploration
#
# Completely naye area mein search karna.
#
# Example
#
# 0.3
#
# 0.5
#
# 0.7
#
# Ho sakta hai aur bhi better result mil jaye.

# %% [markdown]
# # Bayesian Optimization (default TPESampler)

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)

def objective(trial):

    n_estimators = trial.suggest_int("n_estimators", 50, 300)

    max_depth = trial.suggest_int("max_depth", 2, 20)

    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=42
    )

    score = cross_val_score(model, X, y, cv=5).mean()

    return score

study = optuna.create_study(direction="maximize")

study.optimize(objective, n_trials=30)

print(study.best_params)

# %% [markdown]
# # Why Optuna is Popular?
#
# ✅ Automatically uses a smart sampler (TPE, a Bayesian optimization method)
#
# ✅ Needs fewer trials to find good hyperparameters
#
# ✅ Saves training time
#
# ✅ Easy to use with Scikit-learn, XGBoost, LightGBM, TensorFlow, PyTorch, etc.

# %% [markdown]
# # Bayesian Optimization vs Grid Search vs Random Search
#
# | Feature                     | Grid Search       | Random Search       | Bayesian Optimization       |
# | --------------------------- | ----------------- | ------------------- | --------------------------- |
# | Search Style                | Every combination | Random combinations | Learns from previous trials |
# | Speed                       | Slow              | Fast                | Very Fast                   |
# | Uses Previous Results?      | ❌ No              | ❌ No                | ✅ Yes                       |
# | Intelligent Search?         | ❌                 | ❌                   | ✅                           |
# | Best for Large Search Space | ❌                 | ✅                   | ✅✅                          |

# %% [markdown]
# # Bayesian Optimization is an intelligent hyperparameter optimization technique that builds a probabilistic model of the objective function and uses previous trial results to choose the most promising hyperparameters for the next trial, reducing the number of evaluations needed to find the optimum.
